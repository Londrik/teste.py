# %% [markdown]
# <a href="https://colab.research.google.com/github/Londrik/teste.py/blob/main/Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tipos de dados no python
 #Strings = "" tudo oq estiver dentro das aspas e uma string
  #boolean = true ou false
  #int = numero inteiro
  #float = Numeros reais ate 7 casas decimais
  #Double =  Numeros reais ate 12 casas decimais

# %%
#and = E so e verdadeiro quando as duas são verdadeiras
#or = OU so e verdadeiro quando pelo menos 1 das duas e verdadeira
#not = E negação

# %%
#IF = SE
#else = SE NÂO
#ELIF = SE SENÂO

# %%
nome = 0
idade =
print(f"Digite o seu nome {nome} digete a sua idade{idade} vc e{desenvolvedor}")
# Out:
# nome 0

# %%
nome = 0
carlos = 0
input("digite o seu nome ")
# Out:
# digite o seu nome henry
# 'henry '

# %%
nome = 0
salario = 0
empresa = 0
# Out:
# digite o seu nomehenry

# %%
nome = input("Digite o seu nome: ")
salario = float(input("Digite o seu salario: "))
idade = int(input("digite a sua idade:"))
empresa = input("Digite a sua empresa: ")
# Out:
# Digite o seu nome: carlos
# Digite o seu salario: 1350
# digite a sua idade:18
# Digite a sua empresa: T4B

# %%
nome = "henry"
idade = 20
profisao = "programador"
print(nome)
print(idade)
print(profisao)

# %%
#Exercicio com and
idade = int(input("digite a sua idade"))

if idade >= 0 and idade <= 12:
  print("Vc e criança")
elif idade > 12 and idade <= 18:
  print("Vc e adolescente")
elif idade > 18 and idade <= 50:
  print("Vc e adulto")
# Out:
# digite a sua idade20
# Vc e adulto

# %%
homen = input("Digite o seu sexo: ")
if homen == "M":
  print("Vc e homem")
else :
  print("Vc e mulher")
